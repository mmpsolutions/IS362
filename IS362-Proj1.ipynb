# %%
#Moises Perez IS362 Project1: Airline Delayed Chart
import pandas as pd

# %%
#I created a csv file and placed on local direcotry and also uploaded to Github. I named data.csv
#file2=pd.read_table('https://github.com/mmpsolutions/IS362/blob/4e5278b45e4647e12354ba67e730af394eea7ef9/data.csv')
#I uploaded csv to gibhub but had issues reading correctly the same csv file.However, local csv worked correctly.
file = pd.read_csv('data\data.csv') # reading csv from local data subdirectory C:\Users\MMP-SFBook\data

# %%
file.head()
# Out:
#   Airlines           City  On time  Delayed
# 0   Alaska    Los Angeles      497       62
# 1   Alaska        Phoenix      221       12
# 2   Alaska      San Diego      212       20
# 3   Alaska  San Francisco      503      102
# 4   Alaska        Seattle     1841      305

# %%
#Delayed only
delayed = file.sort_values(['Delayed'])
maxdelay = file['Delayed'].max()
file['Airlines']
file['Delayed'].plot()
delaytrue = file['Delayed']==maxdelay
row = file[delaytrue]
#Airlines 1
#Airlines = file['Airlines'] == 'Alaska'
#file[Airlines]['Delayed'].plot()
#Airlines 2 
#Airlines = file['Airlines'] == 'AM WEST'
#file[Airlines]['Delayed'].plot()

# %%
#Airlines 1
Airlines = file['Airlines'] == 'Alaska'
file[Airlines]['Delayed'].plot()

# %%
#Airlines 2 
Airlines = file['Airlines'] == 'AM WEST'
file[Airlines]['Delayed'].plot()

# %%
#to compare both airlines and bar chart
air = file['Airlines'] == 'AM WEST'
file[air]['Delayed'].plot.bar()
file[air]
# Out:
#   Airlines           City  On time  Delayed
# 5  AM WEST    Los Angeles      694      117
# 6  AM WEST        Phoenix     4840      415
# 7  AM WEST      San Diego      383       65
# 8  AM WEST  San Francisco      320      129
# 9  AM WEST        Seattle      201       61

# %%
#to compare both airlines and bar chart
air = file['Airlines'] == 'Alaska'
file[air]['Delayed'].plot.bar()
file[air]
# Out:
#   Airlines           City  On time  Delayed
# 0   Alaska    Los Angeles      497       62
# 1   Alaska        Phoenix      221       12
# 2   Alaska      San Diego      212       20
# 3   Alaska  San Francisco      503      102
# 4   Alaska        Seattle     1841      305
